# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import ipywidgets as widgets
from copy_sequence_task_widget import DatasetWidget, ModelWidget, OptimizerWidget, TrainerWidget

w_dataset = DatasetWidget()
w_model = ModelWidget()
w_optimizer = OptimizerWidget()
w_trainer = TrainerWidget()
        
widgets.VBox([
    w_dataset(),
    widgets.Label(" "),
    w_model(),
    widgets.Label(" "),                                                
    w_optimizer(),                                               
    widgets.Label(" "),
    w_trainer()
])

# %%
import copy_sequence_task_widget.train_model_widget.train_run
from copy_sequence_task_widget import TrainModelWidget, TrainingRunWidget

w_train_model = TrainModelWidget(
    w_dataset,                                                   
    w_model,
    w_optimizer,                                                 
    w_trainer)                                                   
w_train_model()
# Out:
# ...
# Steps 1064/2048  Avg. X-Entropy= 1.80

# %%
w_train_model._trained_models
from copy_sequence_task_widget import ResultsExplorerWidget
results_explorer = ResultsExplorerWidget()
results_explorer.update_models(w_train_model._trained_models)
results_explorer()
# Out:
# dict_keys(['model', 'model_params', 'dataset_params', 'optimizer_params', 'trainer_params'])
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
import ipywidgets as widgets
#from copy_sequence_task_widget import DatasetWidget, ModelWidget, OptimizerWidget, TrainerWidget
from copy_sequence_task_widget import CopySequenceTaskWidget
CopySequenceTaskWidget()()

# %%
from copy_sequence_task_widget import ModelWidget
ModelWidget()()

# %%
from copy_sequence_task_widget import CopySequenceTaskWidget

# %%
main = CopySequenceTaskWidget()
main.display()

# %%
model_data = main._model_explorer._trained_models["model-2::dataset-2"]

# %%
from copy_sequence_task_widget.example_prediction_widget import ExamplePredictionWidget

# %%
ExamplePredictionWidget(model_data).display()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
main = CopySequenceTaskWidget()
main.display()
# Out:
# ...
# <img src="data:image/png;base64,..." width="640">
